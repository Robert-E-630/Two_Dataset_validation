# %% [markdown]
# # Validation of Two Data Sets

# %% [markdown]
# #### Import required libraries and data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#https://data.cityofchicago.org/Public-Safety/Police-ANOV-Misdemeanor-Report-ANOVs/bi66-5gy5
df = pd.read_csv('Police_ANOV_Misdemeanor_Report_-_ANOVs.csv')

# %% [markdown]
# #### Explore Data Set and Create Two Sets - one with artificial errors

# %%
df.describe()
# Out:
#        STREET NUMBER    UNIT NUMBER  Boundaries - ZIP Codes  Community Areas  \
# count  649745.000000  649745.000000           559589.000000    559588.000000
# mean     3639.260941      98.917828               32.582227        41.853219
# std      3500.278698     180.256228               17.734752        19.495181
# min         0.000000       0.000000                1.000000         1.000000
# 25%       800.000000       7.000000               19.000000        27.000000
# 50%      3200.000000      15.000000               30.000000        38.000000
# 75%      5800.000000     191.000000               48.000000        61.000000
# max    119000.000000     933.000000               61.000000        77.000000
#
#            Zip Codes  Census Tracts          Wards
# count  561792.000000  559916.000000  559588.000000
# mean    19245.651946     380.970687      23.532502
# std      5151.188757     235.844116      15.033917
# min      2733.000000       1.000000       1.000000
# 25%     21182.000000     166.000000       9.000000
# 50%     21559.000000     368.000000      23.000000
# 75%     22216.000000     584.000000      36.000000
# max     26912.000000     801.000000      50.000000

# %%
df.head(10)
# Out:
#    NOV NUMBER ISSUED DATE  STREET NUMBER STREET DIRECTION   STREET NAME  \
# 0  P004751507  03/31/2015              0                E       95TH ST
# 1  P004815950  08/06/2015              0                S         LOTUS
# 2  P004822018  08/25/2015              0                E          LAKE
# 3  P004937330  11/17/2015              0                W  CTA PLATFORM
# 4  P004937134  12/15/2015              0                W             0
# 5  P004978399  03/18/2016              0                W          95ST
# 6  P004949791  04/30/2016            500                N       LERAMIE
# 7  P005051389  06/16/2016              0                W       69TH ST
# 8  P004998736  09/27/2016           5400                W       CHICAGO
# 9  P005149325  01/02/2017              0                E     ROOSEVELT
#
#    UNIT NUMBER                   VIOLATION DESCRIPTION LOCATION  \
# 0           19                                       1      NaN
# 1           15   8-4-030(A)    DRINKING IN PUBLIC WAY.      NaN
# 2          211   8-4-030(A)    DRINKING IN PUBLIC WAY.      NaN
# 3          701                                       1      NaN
# 4          701                                       1      NaN
# 5          701                                       1      NaN
# 6           15   8-4-030(A)    DRINKING IN PUBLIC WAY.      NaN
# 7          701                                       1      NaN
# 8           15                 9-76-180  SAFETY BELTS.      NaN
# 9          701  10-8-526/98-126#2.8     SMOKING ON CTA      NaN
#
#    Boundaries - ZIP Codes  Community Areas  Zip Codes  Census Tracts  Wards
# 0                     NaN              NaN        NaN            NaN    NaN
# 1                     NaN              NaN        NaN            NaN    NaN
# 2                     NaN              NaN        NaN            NaN    NaN
# 3                     NaN              NaN        NaN            NaN    NaN
# 4                     NaN              NaN        NaN            NaN    NaN
# 5                     NaN              NaN        NaN            NaN    NaN
# 6                     NaN              NaN        NaN            NaN    NaN
# 7                     NaN              NaN        NaN            NaN    NaN
# 8                     NaN              NaN        NaN            NaN    NaN
# 9                     NaN              NaN        NaN            NaN    NaN

# %%
#count freq of a value occuring in a column, including NULL rows
#https://stackoverflow.com/questions/22391433/count-the-frequency-that-a-value-occurs-in-a-dataframe-column
df['Wards'].value_counts(dropna=False)
# Out:
# NaN     90157
# 2.0     45820
# 36.0    38332
# 23.0    35516
# 4.0     32648
# 32.0    25287
# 14.0    22940
# 31.0    22564
# 9.0     20667
# 46.0    16827
# 37.0    16263
# 10.0    14461
# 39.0    14294
# 45.0    14162
# 13.0    14107
# 33.0    13927
# 25.0    13889
# 43.0    13734
# 3.0     12829
# 22.0    12599
# 35.0     9676
# 1.0      9379
# 47.0     8631
# 26.0     8000
# 8.0      7775
# 50.0     7491
# 48.0     7157
# 7.0      6867
# 30.0     6520
# 28.0     6519
# 41.0     6019
# 11.0     5811
# 5.0      5707
# 6.0      5480
# 49.0     5443
# 34.0     5303
# 16.0     3904
# 12.0     3873
# 21.0     3796
# 17.0     3761
# 20.0     3743
# 15.0     3552
# 40.0     3135
# 38.0     3118
# 18.0     2967
# 29.0     2734
# 44.0     2691
# 19.0     2668
# 24.0     2647
# 27.0     2540
# 42.0     1815
# Name: Wards, dtype: int64

# %%
#python pandas show rows where one column is nan
df[df['Wards'].isnull()]
# Out:
#         NOV NUMBER ISSUED DATE  STREET NUMBER STREET DIRECTION   STREET NAME  \
# 0       P004751507  03/31/2015              0                E       95TH ST
# 1       P004815950  08/06/2015              0                S         LOTUS
# 2       P004822018  08/25/2015              0                E          LAKE
# 3       P004937330  11/17/2015              0                W  CTA PLATFORM
# 4       P004937134  12/15/2015              0                W             0
# ...            ...         ...            ...              ...           ...
# 649730  P005940165  10/06/2020              0                W       69TH ST
# 649734  P005930695  07/23/2020              0                E      ILLINOIS
# 649735  P005752161  09/07/2020           3100                E       78TH ST
# 649740  P005823923  08/25/2020              0                W       79TH ST
# 649742  P006005048  09/02/2020              0                W       95TH ST
#
#         UNIT NUMBER                              VIOLATION DESCRIPTION  \
# 0                19                                                  1
# 1                15              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 2               211              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 3               701                                                  1
# 4               701                                                  1
# ...             ...                                                ...
# 649730          543  10-8-526/016-110-1.18  SMOKING ON CTA (INCLUDI...
# 649734           18              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 649735            4  10-36-185 VII-B 2.    PARK CURFEW.(CHICAGO PAR...
# 649740           19  0000 - NON-MATCHING VIOLATION RECEIVED FROM EX...
# 649742          701  10-8-526/016-110-1.18  SMOKING ON CTA (INCLUDI...
#
#        LOCATION  Boundaries - ZIP Codes  Community Areas  Zip Codes  \
# 0           NaN                     NaN              NaN        NaN
# 1           NaN                     NaN              NaN        NaN
# 2           NaN                     NaN              NaN        NaN
# 3           NaN                     NaN              NaN        NaN
# 4           NaN                     NaN              NaN        NaN
# ...         ...                     ...              ...        ...
# 649730      NaN                     NaN              NaN        NaN
# 649734      NaN                     NaN              NaN        NaN
# 649735      NaN                     NaN              NaN        NaN
# 649740      NaN                     NaN              NaN        NaN
# 649742      NaN                     NaN              NaN        NaN
#
#         Census Tracts  Wards
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
# ...               ...    ...
# 649730            NaN    NaN
# 649734            NaN    NaN
# 649735            NaN    NaN
# 649740            NaN    NaN
# 649742            NaN    NaN
#
# [90157 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['NOV NUMBER', 'ISSUED DATE', 'STREET NUMBER', 'STREET DIRECTION',
#        'STREET NAME', 'UNIT NUMBER', 'VIOLATION DESCRIPTION', 'LOCATION',
#        'Boundaries - ZIP Codes', 'Community Areas', 'Zip Codes',
#        'Census Tracts', 'Wards'],
#       dtype='object')

# %%
#panda count unique values in column
#https://stackoverflow.com/questions/45759966/counting-unique-values-in-a-column-in-pandas-dataframe-like-in-qlik
df['NOV NUMBER'].count()
# Out:
# 649743

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649745 entries, 0 to 649744
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   NOV NUMBER              649743 non-null  object
#  1   ISSUED DATE             649745 non-null  object
#  2   STREET NUMBER           649745 non-null  int64
#  3   STREET DIRECTION        644122 non-null  object
#  4   STREET NAME             649745 non-null  object
#  5   UNIT NUMBER             649745 non-null  int64
#  6   VIOLATION DESCRIPTION   649745 non-null  object
#  7   LOCATION                561792 non-null  object
#  8   Boundaries - ZIP Codes  559589 non-null  float64
#  9   Community Areas         559588 non-null  float64
#  10  Zip Codes               561792 non-null  float64
#  11  Census Tracts           559916 non-null  float64
#  12  Wards                   559588 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 64.4+ MB

# %% [markdown]
# #### Create a 2nd Data Set and replace the 1's with I's

# %%
#https://sparkbyexamples.com/pandas/pandas-replace-substring-in-dataframe/?expand_article=1

df2 = df.replace('1','I', regex=True)

# %%
df2
# Out:
#         NOV NUMBER ISSUED DATE  STREET NUMBER STREET DIRECTION   STREET NAME  \
# 0       P00475I507  03/3I/20I5              0                E       95TH ST
# 1       P0048I5950  08/06/20I5              0                S         LOTUS
# 2       P0048220I8  08/25/20I5              0                E          LAKE
# 3       P004937330  II/I7/20I5              0                W  CTA PLATFORM
# 4       P004937I34  I2/I5/20I5              0                W             0
# ...            ...         ...            ...              ...           ...
# 649740  P005823923  08/25/2020              0                W       79TH ST
# 649741  P005889730  II/2I/2020           2200                S      MICHIGAN
# 649742  P006005048  09/02/2020              0                W       95TH ST
# 649743  P005939260  07/28/2020            100                N      STATE ST
# 649744  P005942296  08/02/2020            100                S      STATE ST
#
#         UNIT NUMBER                              VIOLATION DESCRIPTION  \
# 0                19                                                  I
# 1                15              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 2               211              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 3               701                                                  I
# 4               701                                                  I
# ...             ...                                                ...
# 649740           19  0000 - NON-MATCHING VIOLATION RECEIVED FROM EX...
# 649741            1              7-28-227   CONSTRUCTION SITES-GARBAGE
# 649742          701  I0-8-526/0I6-II0-I.I8  SMOKING ON CTA (INCLUDI...
# 649743          701              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 649744          701  I0-8-526/0I6-II0-I.I3  UNSAFE CONDUCT ON CTA /...
#
#                             LOCATION  Boundaries - ZIP Codes  Community Areas  \
# 0                                NaN                     NaN              NaN
# 1                                NaN                     NaN              NaN
# 2                                NaN                     NaN              NaN
# 3                                NaN                     NaN              NaN
# 4                                NaN                     NaN              NaN
# ...                              ...                     ...              ...
# 649740                           NaN                     NaN              NaN
# 649741  POINT (-87.623802 4I.852652)                    40.0             34.0
# 649742                           NaN                     NaN              NaN
# 649743  POINT (-87.62792I 4I.883328)                    41.0             38.0
# 649744  POINT (-87.627805 4I.880644)                    34.0             38.0
#
#         Zip Codes  Census Tracts  Wards
# 0             NaN            NaN    NaN
# 1             NaN            NaN    NaN
# 2             NaN            NaN    NaN
# 3             NaN            NaN    NaN
# 4             NaN            NaN    NaN
# ...           ...            ...    ...
# 649740        NaN            NaN    NaN
# 649741    21194.0          193.0    9.0
# 649742        NaN            NaN    NaN
# 649743    14310.0           92.0   36.0
# 649744    14311.0           92.0   36.0
#
# [649745 rows x 13 columns]

# %% [markdown]
# #### Replace Random # of rows from 1st Data with 2nd Data Set

# %%
#pandas dataframe replace random rows with rows from second data frame
#https://stackoverflow.com/questions/46450260/how-can-i-randomly-change-the-values-of-some-rows-in-a-pandas-dataframe
df3=df.copy(deep=True)
df3.update(df2.sample(frac=.25))
df3
# Out:
#         NOV NUMBER ISSUED DATE  STREET NUMBER STREET DIRECTION   STREET NAME  \
# 0       P00475I507  03/3I/20I5            0.0                E       95TH ST
# 1       P004815950  08/06/2015            0.0                S         LOTUS
# 2       P004822018  08/25/2015            0.0                E          LAKE
# 3       P004937330  11/17/2015            0.0                W  CTA PLATFORM
# 4       P004937134  12/15/2015            0.0                W             0
# ...            ...         ...            ...              ...           ...
# 649740  P005823923  08/25/2020            0.0                W       79TH ST
# 649741  P005889730  II/2I/2020         2200.0                S      MICHIGAN
# 649742  P006005048  09/02/2020            0.0                W       95TH ST
# 649743  P005939260  07/28/2020          100.0                N      STATE ST
# 649744  P005942296  08/02/2020          100.0                S      STATE ST
#
#         UNIT NUMBER                              VIOLATION DESCRIPTION  \
# 0              19.0                                                  I
# 1              15.0              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 2             211.0              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 3             701.0                                                  1
# 4             701.0                                                  1
# ...             ...                                                ...
# 649740         19.0  0000 - NON-MATCHING VIOLATION RECEIVED FROM EX...
# 649741          1.0              7-28-227   CONSTRUCTION SITES-GARBAGE
# 649742        701.0  10-8-526/016-110-1.18  SMOKING ON CTA (INCLUDI...
# 649743        701.0              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 649744        701.0  I0-8-526/0I6-II0-I.I3  UNSAFE CONDUCT ON CTA /...
#
#                             LOCATION  Boundaries - ZIP Codes  Community Areas  \
# 0                                NaN                     NaN              NaN
# 1                                NaN                     NaN              NaN
# 2                                NaN                     NaN              NaN
# 3                                NaN                     NaN              NaN
# 4                                NaN                     NaN              NaN
# ...                              ...                     ...              ...
# 649740                           NaN                     NaN              NaN
# 649741  POINT (-87.623802 4I.852652)                    40.0             34.0
# 649742                           NaN                     NaN              NaN
# 649743  POINT (-87.627921 41.883328)                    41.0             38.0
# 649744  POINT (-87.627805 4I.880644)                    34.0             38.0
#
#         Zip Codes  Census Tracts  Wards
# 0             NaN            NaN    NaN
# 1             NaN            NaN    NaN
# 2             NaN            NaN    NaN
# 3             NaN            NaN    NaN
# 4             NaN            NaN    NaN
# ...           ...            ...    ...
# 649740        NaN            NaN    NaN
# 649741    21194.0          193.0    9.0
# 649742        NaN            NaN    NaN
# 649743    14310.0           92.0   36.0
# 649744    14311.0           92.0   36.0
#
# [649745 rows x 13 columns]

# %% [markdown]
# ### Join Original Dataset onto 'Corrupted' Dataset

# %% [markdown]
# #### In both Datasets's Column Headers - Replace spaces with underlines

# %%
#python dataframe column names replace space with underscore
df.columns
# Out:
# Index(['NOV NUMBER', 'ISSUED DATE', 'STREET NUMBER', 'STREET DIRECTION',
#        'STREET NAME', 'UNIT NUMBER', 'VIOLATION DESCRIPTION', 'LOCATION',
#        'Boundaries - ZIP Codes', 'Community Areas', 'Zip Codes',
#        'Census Tracts', 'Wards'],
#       dtype='object')

# %%
#https://stackoverflow.com/questions/65209035/renaming-column-names-from-a-data-set-in-pandas
#https://stackoverflow.com/questions/41476150/remove-or-replace-spaces-in-column-names
df.columns = [i.replace(' ','_') for i in df.columns]
df3.columns = [i.replace(' ','_') for i in df3.columns]

# %% [markdown]
# #### Update column names of 2nd dataset

# %%
df3.columns
# Out:
# Index(['NOV_NUMBER', 'ISSUED_DATE', 'STREET_NUMBER', 'STREET_DIRECTION',
#        'STREET_NAME', 'UNIT_NUMBER', 'VIOLATION_DESCRIPTION', 'LOCATION',
#        'Boundaries_-_ZIP_Codes', 'Community_Areas', 'Zip_Codes',
#        'Census_Tracts', 'Wards'],
#       dtype='object')

# %%
#list comprehension
['hyp_'+ str(col) for col in df.columns]
# Out:
# ['hyp_NOV_NUMBER',
#  'hyp_ISSUED_DATE',
#  'hyp_STREET_NUMBER',
#  'hyp_STREET_DIRECTION',
#  'hyp_STREET_NAME',
#  'hyp_UNIT_NUMBER',
#  'hyp_VIOLATION_DESCRIPTION',
#  'hyp_LOCATION',
#  'hyp_Boundaries_-_ZIP_Codes',
#  'hyp_Community_Areas',
#  'hyp_Zip_Codes',
#  'hyp_Census_Tracts',
#  'hyp_Wards']

# %%
#pandas dataframe add prefix to column names
#https://stackoverflow.com/questions/34049618/how-to-add-a-suffix-or-prefix-to-each-column-name

df.columns = ['hyp_'+ str(col) for col in df.columns]
df3.columns = ['OAS_'+ str(col) for col in df3.columns]

# %% [markdown]
# #### Join the two Data Sets
# - possibly outer join?
# - 3rd set of columns will be indicator columns comparing Hyperion Column to OAS Column
# - Final Data Set columns will be arranged:
#     - Hyperion Columns
#     - Comparison Columns
#     - OAS Columns

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
df_combo=df.merge(df3, how='outer',left_on='hyp_NOV_NUMBER', right_on='OAS_NOV_NUMBER')

# %%
#python pandas view all columns of dataframe
#https://towardsdatascience.com/how-to-show-all-columns-rows-of-a-pandas-dataframe-c49d4507fcf
pd.set_option('display.max_columns', None)
df_combo
# Out:
#        hyp_NOV_NUMBER hyp_ISSUED_DATE  hyp_STREET_NUMBER hyp_STREET_DIRECTION  \
# 0          P004751507      03/31/2015                0.0                    E
# 1          P004815950      08/06/2015                0.0                    S
# 2          P004822018      08/25/2015                0.0                    E
# 3          P004937330      11/17/2015                0.0                    W
# 4          P004937134      12/15/2015                0.0                    W
# ...               ...             ...                ...                  ...
# 725642            NaN             NaN                NaN                  NaN
# 725643            NaN             NaN                NaN                  NaN
# 725644            NaN             NaN                NaN                  NaN
# 725645            NaN             NaN                NaN                  NaN
# 725646            NaN             NaN                NaN                  NaN
#
#        hyp_STREET_NAME  hyp_UNIT_NUMBER  \
# 0              95TH ST             19.0
# 1                LOTUS             15.0
# 2                 LAKE            211.0
# 3         CTA PLATFORM            701.0
# 4                    0            701.0
# ...                ...              ...
# 725642             NaN              NaN
# 725643             NaN              NaN
# 725644             NaN              NaN
# 725645             NaN              NaN
# 725646             NaN              NaN
#
#                     hyp_VIOLATION_DESCRIPTION hyp_LOCATION  \
# 0                                           1          NaN
# 1       8-4-030(A)    DRINKING IN PUBLIC WAY.          NaN
# 2       8-4-030(A)    DRINKING IN PUBLIC WAY.          NaN
# 3                                           1          NaN
# 4                                           1          NaN
# ...                                       ...          ...
# 725642                                    NaN          NaN
# 725643                                    NaN          NaN
# 725644                                    NaN          NaN
# 725645                                    NaN          NaN
# 725646                                    NaN          NaN
#
#         hyp_Boundaries_-_ZIP_Codes  hyp_Community_Areas  hyp_Zip_Codes  \
# 0                              NaN                  NaN            NaN
# 1                              NaN                  NaN            NaN
# 2                              NaN                  NaN            NaN
# 3                              NaN                  NaN            NaN
# 4                              NaN                  NaN            NaN
# ...                            ...                  ...            ...
# 725642                         NaN                  NaN            NaN
# 725643                         NaN                  NaN            NaN
# 725644                         NaN                  NaN            NaN
# 725645                         NaN                  NaN            NaN
# 725646                         NaN                  NaN            NaN
#
#         hyp_Census_Tracts  hyp_Wards OAS_NOV_NUMBER OAS_ISSUED_DATE  \
# 0                     NaN        NaN            NaN             NaN
# 1                     NaN        NaN     P004815950      08/06/2015
# 2                     NaN        NaN     P004822018      08/25/2015
# 3                     NaN        NaN     P004937330      11/17/2015
# 4                     NaN        NaN     P004937134      12/15/2015
# ...                   ...        ...            ...             ...
# 725642                NaN        NaN     P0058749I8      08/I8/2020
# 725643                NaN        NaN     P005849I29      08/05/2020
# 725644                NaN        NaN     P0058374I8      I0/I9/2020
# 725645                NaN        NaN     P0060033I0      I0/02/2020
# 725646                NaN        NaN     P00589694I      I2/02/2020
#
#         OAS_STREET_NUMBER OAS_STREET_DIRECTION OAS_STREET_NAME  \
# 0                     NaN                  NaN             NaN
# 1                     0.0                    S           LOTUS
# 2                     0.0                    E            LAKE
# 3                     0.0                    W    CTA PLATFORM
# 4                     0.0                    W               0
# ...                   ...                  ...             ...
# 725642              500.0                    S         PULASKI
# 725643             7400.0                    S         EMERALD
# 725644                0.0                    W        TERMINAL
# 725645             3600.0                    W         LAKE ST
# 725646             3700.0                    W       NORTH AVE
#
#         OAS_UNIT_NUMBER                          OAS_VIOLATION_DESCRIPTION  \
# 0                   NaN                                                NaN
# 1                  15.0              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 2                 211.0              8-4-030(A)    DRINKING IN PUBLIC WAY.
# 3                 701.0                                                  1
# 4                 701.0                                                  1
# ...                 ...                                                ...
# 725642            610.0  I0-8-526/0I6-II0-I.04  ALCOHOL CONSUMPTION OR ...
# 725643            192.0                    8-8-060    STREET SOLICITATION.
# 725644             50.0  9-II4-280     LIVERY - SOLICITATION OF PASSENG...
# 725645            701.0  I0-8-526/0I6-II0-I.27(4)  TRESPASS / ENTERING ...
# 725646             25.0                    8-4-056(B)  FALSE BURGLAR ALARM
#
#                         OAS_LOCATION  OAS_Boundaries_-_ZIP_Codes  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
# ...                              ...                         ...
# 725642  POINT (-87.7254I9 4I.874387)                        30.0
# 725643  POINT (-87.643064 4I.759525)                        11.0
# 725644                           NaN                         NaN
# 725645  POINT (-87.7I6389 4I.8850I6)                        30.0
# 725646   POINT (-87.7I9048 4I.9I004)                         1.0
#
#         OAS_Community_Areas  OAS_Zip_Codes  OAS_Census_Tracts  OAS_Wards
# 0                       NaN            NaN                NaN        NaN
# 1                       NaN            NaN                NaN        NaN
# 2                       NaN            NaN                NaN        NaN
# 3                       NaN            NaN                NaN        NaN
# 4                       NaN            NaN                NaN        NaN
# ...                     ...            ...                ...        ...
# 725642                 27.0        21572.0              736.0       23.0
# 725643                 66.0        21559.0              511.0       32.0
# 725644                  NaN            NaN                NaN        NaN
# 725645                 28.0        21572.0              176.0       23.0
# 725646                 24.0        22535.0              391.0       49.0
#
# [725647 rows x 26 columns]

# %%
df_combo['hyp_NOV_NUMBER'].count()
# Out:
# 649743

# %%
#python pandas count null and non-null values in column
#python pandas count null values in column
#https://stackoverflow.com/questions/26266362/how-do-i-count-the-nan-values-in-a-column-in-pandas-dataframe
df_combo['hyp_NOV_NUMBER'].isna().sum()
# Out:
# 75904

# %% [markdown]
# ### Create indicator columns comparing Hyperion Column to OAS Column

# %%
df_combo.columns
# Out:
# Index(['hyp_NOV_NUMBER', 'hyp_ISSUED_DATE', 'hyp_STREET_NUMBER',
#        'hyp_STREET_DIRECTION', 'hyp_STREET_NAME', 'hyp_UNIT_NUMBER',
#        'hyp_VIOLATION_DESCRIPTION', 'hyp_LOCATION',
#        'hyp_Boundaries_-_ZIP_Codes', 'hyp_Community_Areas', 'hyp_Zip_Codes',
#        'hyp_Census_Tracts', 'hyp_Wards', 'OAS_NOV_NUMBER', 'OAS_ISSUED_DATE',
#        'OAS_STREET_NUMBER', 'OAS_STREET_DIRECTION', 'OAS_STREET_NAME',
#        'OAS_UNIT_NUMBER', 'OAS_VIOLATION_DESCRIPTION', 'OAS_LOCATION',
#        'OAS_Boundaries_-_ZIP_Codes', 'OAS_Community_Areas', 'OAS_Zip_Codes',
#        'OAS_Census_Tracts', 'OAS_Wards'],
#       dtype='object')

# %% [markdown]
# #### Test code below

# %%
#python check first 3 characters of string
#if 1st 3 letters of column is "hyp" -then compare current column to oas column
for colu in df_combo.columns:
    #print(colu)
    #print(colu[0:3])
    if(colu[0:3]=='hyp'):
        print(colu[0:3])
        print(colu[4:len(colu)])
        print(colu)
        print('OAS_'+colu[4:len(colu)])
        print()
        #print('\n')
# Out:
# hyp
# NOV_NUMBER
# hyp_NOV_NUMBER
# OAS_NOV_NUMBER
#
# hyp
# ISSUED_DATE
# hyp_ISSUED_DATE
# OAS_ISSUED_DATE
#
# hyp
# STREET_NUMBER
# hyp_STREET_NUMBER
# OAS_STREET_NUMBER
#
# hyp
# STREET_DIRECTION
# hyp_STREET_DIRECTION
# OAS_STREET_DIRECTION
#
# hyp
# STREET_NAME
# hyp_STREET_NAME
# OAS_STREET_NAME
#
# hyp
# UNIT_NUMBER
# hyp_UNIT_NUMBER
# OAS_UNIT_NUMBER
#
# hyp
# VIOLATION_DESCRIPTION
# hyp_VIOLATION_DESCRIPTION
# OAS_VIOLATION_DESCRIPTION
#
# hyp
# LOCATION
# hyp_LOCATION
# OAS_LOCATION
#
# hyp
# Boundaries_-_ZIP_Codes
# hyp_Boundaries_-_ZIP_Codes
# OAS_Boundaries_-_ZIP_Codes
#
# hyp
# Community_Areas
# hyp_Community_Areas
# OAS_Community_Areas
#
# hyp
# Zip_Codes
# hyp_Zip_Codes
# OAS_Zip_Codes
#
# hyp
# Census_Tracts
# hyp_Census_Tracts
# OAS_Census_Tracts
#
# hyp
# Wards
# hyp_Wards
# OAS_Wards

# %%
for colu in df_combo.columns:
    print(colu)
# Out:
# hyp_NOV_NUMBER
# hyp_ISSUED_DATE
# hyp_STREET_NUMBER
# hyp_STREET_DIRECTION
# hyp_STREET_NAME
# hyp_UNIT_NUMBER
# hyp_VIOLATION_DESCRIPTION
# hyp_LOCATION
# hyp_Boundaries_-_ZIP_Codes
# hyp_Community_Areas
# hyp_Zip_Codes
# hyp_Census_Tracts
# hyp_Wards
# OAS_NOV_NUMBER
# OAS_ISSUED_DATE
# OAS_STREET_NUMBER
# OAS_STREET_DIRECTION
# OAS_STREET_NAME
# OAS_UNIT_NUMBER
# OAS_VIOLATION_DESCRIPTION
# OAS_LOCATION
# OAS_Boundaries_-_ZIP_Codes
# OAS_Community_Areas
# OAS_Zip_Codes
# OAS_Census_Tracts
# OAS_Wards

# %% [markdown]
# #### Create indicator columns

# %%
#need to first create a copy, because the columns of df_combo_2 will be changing when we add indicator columns
df_combo_2=df_combo.copy(deep=True)

#use enumerate(i,colu)
for colu in df_combo.columns:
    #print(colu)
    #print(colu[0:3])
    if(colu[0:3]=='hyp'):
        print('column_1')
        df_combo_2['diff_'+colu[4:len(colu)]] = df_combo.apply(lambda x: 0 if x[colu]==x['OAS_'+colu[4:len(colu)]] else 1, axis=1)
# Out:
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1
# column_1

# %%
colu[5:len(colu)]
# Out:
# 'ards'

# %% [markdown]
# ### Print Sum of each indicator column

# %%
for colu in df_combo_2.columns:
    if(colu[0:4]=='diff'):
        print(colu[5:len(colu)],'\t\t\t',df_combo_2[colu].sum())
# Out:
# NOV_NUMBER 			 151804
# ISSUED_DATE 			 236364
# STREET_NUMBER 			 151802
# STREET_DIRECTION 			 156761
# STREET_NAME 			 155306
# UNIT_NUMBER 			 151800
# VIOLATION_DESCRIPTION 			 195752
# LOCATION 			 304262
# Boundaries_-_ZIP_Codes 			 231439
# Community_Areas 			 231440
# Zip_Codes 			 229454
# Census_Tracts 			 231146
# Wards 			 231440

# %% [markdown]
# ### For each column pair, print 1st ten mismatched rows

# %%
df_combo_2.columns
# Out:
# Index(['hyp_NOV_NUMBER', 'hyp_ISSUED_DATE', 'hyp_STREET_NUMBER',
#        'hyp_STREET_DIRECTION', 'hyp_STREET_NAME', 'hyp_UNIT_NUMBER',
#        'hyp_VIOLATION_DESCRIPTION', 'hyp_LOCATION',
#        'hyp_Boundaries_-_ZIP_Codes', 'hyp_Community_Areas', 'hyp_Zip_Codes',
#        'hyp_Census_Tracts', 'hyp_Wards', 'OAS_NOV_NUMBER', 'OAS_ISSUED_DATE',
#        'OAS_STREET_NUMBER', 'OAS_STREET_DIRECTION', 'OAS_STREET_NAME',
#        'OAS_UNIT_NUMBER', 'OAS_VIOLATION_DESCRIPTION', 'OAS_LOCATION',
#        'OAS_Boundaries_-_ZIP_Codes', 'OAS_Community_Areas', 'OAS_Zip_Codes',
#        'OAS_Census_Tracts', 'OAS_Wards', 'diff_NOV_NUMBER', 'diff_ISSUED_DATE',
#        'diff_STREET_NUMBER', 'diff_STREET_DIRECTION', 'diff_STREET_NAME',
#        'diff_UNIT_NUMBER', 'diff_VIOLATION_DESCRIPTION', 'diff_LOCATION',
#        'diff_Boundaries_-_ZIP_Codes', 'diff_Community_Areas', 'diff_Zip_Codes',
#        'diff_Census_Tracts', 'diff_Wards'],
#       dtype='object')

# %%
for colu in df_combo_2.columns:
    if(colu[0:3]=='hyp'):
        print(colu)
        print(colu[4:len(colu)])
        print(colu,'OAS_'+colu[4:len(colu)])
       # print(df_combo_2[[colu,'OAS_'+colu[4:len(colu)]]])
        df_pair=df_combo_2[[colu,'OAS_'+colu[4:len(colu)]]]
        print(df_pair[df_combo_2['diff_'+colu[4:len(colu)]]==1].head(10))
        print('\n')
        #print(df_combo_2[colu])
# Out:
# hyp_NOV_NUMBER
# NOV_NUMBER
# hyp_NOV_NUMBER OAS_NOV_NUMBER
#    hyp_NOV_NUMBER OAS_NOV_NUMBER
# 0      P004751507            NaN
# 7      P005051389            NaN
# 11     P005215381            NaN
# 12     P005124603            NaN
# 15     P005831197            NaN
# 16     P004617910            NaN
# 21     P004574122            NaN
# 36     P004689519            NaN
# 39     P004712715            NaN
# 43     P004579713            NaN
#
#
# hyp_ISSUED_DATE
# ISSUED_DATE
# hyp_ISSUED_DATE OAS_ISSUED_DATE
#    hyp_ISSUED_DATE OAS_ISSUED_DATE
# 0       03/31/2015             NaN
# 7       06/16/2016             NaN
# 11      10/18/2017             NaN
# 12      01/13/2018             NaN
# 15      08/07/2019             NaN
# 16      01/16/2015             NaN
# 21      01/08/2015             NaN
# 23      02/07/2015      02/07/20I5
# 32      01/26/2015      0I/26/20I5
# 33      02/08/2015      02/08/20I5
#
#
# hyp_STREET_NUMBER
# STREET_NUMBER
# hyp_STREET_NUMBER OAS_STREET_NUMBER
#     hyp_STREET_NUMBER  OAS_STREET_NUMBER
# 0                 0.0                NaN
# 7                 0.0                NaN
# 11             5400.0                NaN
# 12                0.0                NaN
# 15                0.0                NaN
# 16             2000.0                NaN
# 21                0.0                NaN
# 36             3000.0                NaN
# 39              800.0                NaN
# 43                0.0                NaN
#
#
# hyp_STREET_DIRECTION
# STREET_DIRECTION
# hyp_STREET_DIRECTION OAS_STREET_DIRECTION
#    hyp_STREET_DIRECTION OAS_STREET_DIRECTION
# 0                     E                  NaN
# 7                     W                  NaN
# 11                    W                  NaN
# 12                    N                  NaN
# 15                    E                  NaN
# 16                    E                  NaN
# 21                    W                  NaN
# 36                    S                  NaN
# 39                    N                  NaN
# 43                    W                  NaN
#
#
# hyp_STREET_NAME
# STREET_NAME
# hyp_STREET_NAME OAS_STREET_NAME
#    hyp_STREET_NAME OAS_STREET_NAME
# 0          95TH ST             NaN
# 7          69TH ST             NaN
# 11        61ST STA             NaN
# 12       DAMEN AVE             NaN
# 15     ILLINOIS ST             NaN
# 16         79TH ST             NaN
# 21     TERMINAL ST             NaN
# 36          KEDZIE             NaN
# 39           STATE             NaN
# 43         95TH ST             NaN
#
#
# hyp_UNIT_NUMBER
# UNIT_NUMBER
# hyp_UNIT_NUMBER OAS_UNIT_NUMBER
#     hyp_UNIT_NUMBER  OAS_UNIT_NUMBER
# 0              19.0              NaN
# 7             701.0              NaN
# 11              8.0              NaN
# 12             57.0              NaN
# 15             18.0              NaN
# 16            212.0              NaN
# 21             50.0              NaN
# 36             10.0              NaN
# 39             18.0              NaN
# 43             15.0              NaN
#
#
# hyp_VIOLATION_DESCRIPTION
# VIOLATION_DESCRIPTION
# hyp_VIOLATION_DESCRIPTION OAS_VIOLATION_DESCRIPTION
#                             hyp_VIOLATION_DESCRIPTION  \
# 0                                                   1
# 7                                                   1
# 11                                                  1
# 12                                                  1
# 15                                                  1
# 16                9-60-080    WALKING ALONG ROADWAYS.
# 21           9-112-560     AIRPORT SERVICE (TAXICABS)
# 33             10-8-526/98-126#2.8     SMOKING ON CTA
# 36  9-76-230 (A)  MOBILE TELEPHONE USED W/OUT HAND...
# 39         10-28-281.1     PUBLIC PROTECTION MEASURES
#
#                  OAS_VIOLATION_DESCRIPTION
# 0                                      NaN
# 7                                      NaN
# 11                                     NaN
# 12                                     NaN
# 15                                     NaN
# 16                                     NaN
# 21                                     NaN
# 33  I0-8-526/98-I26#2.8     SMOKING ON CTA
# 36                                     NaN
# 39                                     NaN
#
#
# hyp_LOCATION
# LOCATION
# hyp_LOCATION OAS_LOCATION
#   hyp_LOCATION OAS_LOCATION
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9          NaN          NaN
#
#
# hyp_Boundaries_-_ZIP_Codes
# Boundaries_-_ZIP_Codes
# hyp_Boundaries_-_ZIP_Codes OAS_Boundaries_-_ZIP_Codes
#    hyp_Boundaries_-_ZIP_Codes  OAS_Boundaries_-_ZIP_Codes
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# 5                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                         NaN
# 8                         NaN                         NaN
# 9                         NaN                         NaN
#
#
# hyp_Community_Areas
# Community_Areas
# hyp_Community_Areas OAS_Community_Areas
#    hyp_Community_Areas  OAS_Community_Areas
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
# 5                  NaN                  NaN
# 6                  NaN                  NaN
# 7                  NaN                  NaN
# 8                  NaN                  NaN
# 9                  NaN                  NaN
#
#
# hyp_Zip_Codes
# Zip_Codes
# hyp_Zip_Codes OAS_Zip_Codes
#    hyp_Zip_Codes  OAS_Zip_Codes
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
# 5            NaN            NaN
# 6            NaN            NaN
# 7            NaN            NaN
# 8            NaN            NaN
# 9            NaN            NaN
#
#
# hyp_Census_Tracts
# Census_Tracts
# hyp_Census_Tracts OAS_Census_Tracts
#    hyp_Census_Tracts  OAS_Census_Tracts
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# 5                NaN                NaN
# 6                NaN                NaN
# 7                NaN                NaN
# 8                NaN                NaN
# 9                NaN                NaN
#
#
# hyp_Wards
# Wards
# hyp_Wards OAS_Wards
#    hyp_Wards  OAS_Wards
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8        NaN        NaN
# 9        NaN        NaN

# %% [markdown]
# #### Filter first for where primary keys match, to find mismatches on other columns besides simple primary Key Mismatches
